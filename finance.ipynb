# %% [markdown]
# Question 1 - Extracting Tesla Stock Data Using yfinance - 2 Points

# %%
import yfinance as yf

tesla = yf.Ticker("TSLA")
tesla_stock_data = tesla.history(period="max")

tesla_stock_data
tesla_stock_data.head()
# Out:
#                                Open      High       Low     Close     Volume
# Date
# 2010-06-29 00:00:00-04:00  1.266667  1.666667  1.169333  1.592667  281494500  \
# 2010-06-30 00:00:00-04:00  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01 00:00:00-04:00  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02 00:00:00-04:00  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06 00:00:00-04:00  1.333333  1.333333  1.055333  1.074000  103003500
#
#                            Dividends  Stock Splits
# Date
# 2010-06-29 00:00:00-04:00        0.0           0.0
# 2010-06-30 00:00:00-04:00        0.0           0.0
# 2010-07-01 00:00:00-04:00        0.0           0.0
# 2010-07-02 00:00:00-04:00        0.0           0.0
# 2010-07-06 00:00:00-04:00        0.0           0.0

# %% [markdown]
# Question 2 - Extracting Tesla Revenue Data Using Webscraping - 1 Points

# %%
import requests
from bs4 import BeautifulSoup

URL = 'https://companiesmarketcap.com/tesla/revenue/'

response = requests.get(URL)
soup = BeautifulSoup(response.content, 'html.parser')
tesla_revenue_data = soup.find('span', class_='background-ya').text
print(tesla_revenue_data)
# Out:
# $94.02 B

# %% [markdown]
# Question 3 - Extracting GameStop Stock Data Using yfinance - 2 Points

# %%
gamestop = yf.Ticker("GME")
gamestop_stock_data = gamestop.history(period="max")
gamestop_stock_data.head()
# Out:
#                                Open      High       Low     Close    Volume
# Date
# 2002-02-13 00:00:00-05:00  1.620128  1.693350  1.603296  1.691666  76216000  \
# 2002-02-14 00:00:00-05:00  1.712707  1.716074  1.670626  1.683250  11021600
# 2002-02-15 00:00:00-05:00  1.683250  1.687458  1.658001  1.674834   8389600
# 2002-02-19 00:00:00-05:00  1.666418  1.666418  1.578047  1.607504   7410400
# 2002-02-20 00:00:00-05:00  1.615920  1.662209  1.603296  1.662209   6892800
#
#                            Dividends  Stock Splits
# Date
# 2002-02-13 00:00:00-05:00        0.0           0.0
# 2002-02-14 00:00:00-05:00        0.0           0.0
# 2002-02-15 00:00:00-05:00        0.0           0.0
# 2002-02-19 00:00:00-05:00        0.0           0.0
# 2002-02-20 00:00:00-05:00        0.0           0.0

# %% [markdown]
# Question 4 - Extracting GameStop Revenue Data Using Webscraping - 1 Points

# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://companiesmarketcap.com/gamestop/revenue/'

response = requests.get(URL)
soup = BeautifulSoup(response.content, 'html.parser')

revenue_2023 = soup.find('span', class_='background-ya').text
print(revenue_2023)
# Out:
# $5.81 B

# %% [markdown]
# Question 5 - Tesla Stock and Revenue Dashboard - 2 Points

# %%
tesla_revenue_value = 94.02  
tesla_revenue_data = pd.DataFrame({
    "Date": ["2023-01-01"],
    "Revenue": [tesla_revenue_value]
})

# Función para crear el dashboard
def make_graph(stock_data, revenue_data, stock):
    fig = make_subplots(rows=2, cols=1, shared_xaxes=True, subplot_titles=("Historical Share Price", "Historical Revenue"), vertical_spacing=.3)
    fig.add_trace(go.Scatter(x=stock_data.index, y=stock_data["Close"], name="Share Price"), row=1, col=1)
    fig.add_trace(go.Scatter(x=pd.to_datetime(revenue_data["Date"]), y=revenue_data["Revenue"], name="Revenue"), row=2, col=1)
    fig.update_xaxes(title_text="Date", row=1, col=1)
    fig.update_xaxes(title_text="Date", row=2, col=1)
    fig.update_yaxes(title_text="Price ($US)", row=1, col=1)
    fig.update_yaxes(title_text="Revenue ($US Billions)", row=2, col=1)
    fig.update_layout(showlegend=False, height=900, title=stock, xaxis_rangeslider_visible=True)
    fig.show()

make_graph(tesla_stock_data, tesla_revenue_data, "Tesla")

# %% [markdown]
# Question 6 - GameStop Stock and Revenue Dashboard- 2 Points

# %%
gamestop = yf.Ticker("GME")
gme_data = gamestop.history(period="max")

URL_GME = 'https://companiesmarketcap.com/gamestop/revenue/'
response_gme = requests.get(URL_GME)
soup_gme = BeautifulSoup(response_gme.content, 'html.parser')
gme_revenue_data_str = soup_gme.find('span', class_='background-ya').text
gme_revenue_data_float = float(gme_revenue_data_str.split()[0].replace('$','').replace('B','')) 
gme_revenue = pd.DataFrame({
    "Date": ["2023-01-01"],  
    "Revenue": [gme_revenue_data_float]
})
make_graph(gme_data, gme_revenue, "GameStop")

# %% [markdown]
# Question 7 - Sharing your Assignment Notebook - 2 Points
